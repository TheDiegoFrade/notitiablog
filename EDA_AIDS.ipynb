# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import xlrd

from bokeh.io import output_file, show
from bokeh.models import HoverTool
from bokeh.plotting import figure

# %%
aids_data = pd.read_csv(r'C:\Users\diego\Downloads\aids.csv')
aids_data = pd.DataFrame(aids_data)
aids_data.columns = ['Orphans','Deaths_Adults','Deaths_All_Ages','Deaths_Children','Deaths_Female','Deaths_Male','Country',
                     'HIV_prevalence_adults','Incidence_rate_adults','New_HIV_Infected_Adults','New_HIV_Infected_All_Ages',
                     'New_HIV_Infected_Children','New_HIV_Infect_Fem_Adults','New_HIV_Infect_Male_Adults','People_Living_WithHIV_Adults',
                     'People_living_WithHIV_Children','People_living_HIV_FemAdults','People_living_HIV_MaleAdults','Total','Year',
                     'Young_men','Young_women']

Latin_America_countries = ['Brazil','Mexico','Colombia','Argentina','Peru','Venezuela','Chile','Ecuador','Guatemala','Cuba','Haiti',
                     'Bolivia','Dominican Republic','Honduras','Paraguay','Nicaragua','El Salvador','Costa Rica','Panama'
                     ,'Uruguay']


Latin_America = aids_data[(aids_data['Country'].isin(Latin_America_countries))]


Brazil = Latin_America[(Latin_America['Country'] == 'Brazil')]
Mexico = Latin_America[(Latin_America['Country'] == 'Mexico')]
Colombia = Latin_America[(Latin_America['Country'] == 'Colombia')]
Argentina = Latin_America[(Latin_America['Country'] == 'Argentina')]
Peru = Latin_America[(Latin_America['Country'] == 'Peru')]
Venezuela = Latin_America[(Latin_America['Country'] == 'Venezuela')]
Chile = Latin_America[(Latin_America['Country'] == 'Chile')]
Ecuador = Latin_America[(Latin_America['Country'] == 'Ecuador')]
Guatemala = Latin_America[(Latin_America['Country'] == 'Guatemala')]
Cuba = Latin_America[(Latin_America['Country'] == 'Cuba')]
Haiti = Latin_America[(Latin_America['Country'] == 'Haiti')]
Bolivia = Latin_America[(Latin_America['Country'] == 'Bolivia')]
Dominican_Republic = Latin_America[(Latin_America['Country'] == 'Dominican Republic')]
Honduras = Latin_America[(Latin_America['Country'] == 'Honduras')]
Paraguay = Latin_America[(Latin_America['Country'] == 'Paraguay')]
Nicaragua = Latin_America[(Latin_America['Country'] == 'Nicaragua')]
El_Salvador = Latin_America[(Latin_America['Country'] == 'El Salvador')]
Costa_Rica = Latin_America[(Latin_America['Country'] == 'Costa Rica')]
Panama = Latin_America[(Latin_America['Country'] == 'Panama')]
Uruguay = Latin_America[(Latin_America['Country'] == 'Uruguay')]

# %%
Latin_America_data = [Brazil,Mexico,Colombia,Argentina,Peru,Venezuela,Chile,Ecuador,Guatemala,Cuba,Haiti,Bolivia,
                      Dominican_Republic,Honduras,Paraguay,Nicaragua,El_Salvador,Costa_Rica,Panama,Uruguay]

Mexico.set_index('Year', inplace = True)

# %%
ax = Mexico.hist(column='Orphans', bins=25, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("VIH Orphans in Mexico (1990-2015)", fontsize = 25, weight='bold')

    # Set x-axis label
    x.set_xlabel("Number of VIH Orphans in Mexico", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Data Frequency", labelpad=20, weight='bold', size=12)

    plt.show()
Mexico.iloc[:,[0,1,2,3]].hist(bins=15, color='steelblue', edgecolor='black', linewidth=1.0,
           xlabelsize=1, ylabelsize=1, grid=False)
plt.tight_layout(rect=(0, 0, 1, 1))

plt.show()
# Out:
# C:\Users\diego\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Users\diego\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Users\diego\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ...

# %%
fig = plt.figure(figsize=(6,4))
title = fig.suptitle('HIV Prevalence Adults', fontsize= 14)
fig.subplots_adjust(top = 0.85, wspace = 0.3)

ax = fig.add_subplot(1,1,1)
ax.set_xlabel('HIV Prevalence Adults')
ax.set_ylabel('Frequency')
ax.text(1.2, 800, r'$\mu$=' + str(round(Mexico['HIV_prevalence_adults'].mean(),2)), fontsize=12)

freq, bins, patches = ax.hist(Mexico['HIV_prevalence_adults'], color='steelblue', bins = 15,
                              edgecolor= 'black', linewidth = 1)
fig = plt.figure(figsize=(6,4))
title = fig.suptitle('HIV Prevalence Adults', fontsize = 14)
fig.subplots_adjust(top = 0.85, wspace = 0.3)

ax1 = fig.add_subplot(1,1,1)
ax1.set_xlabel('HIV Prevalence')
ax1.set_ylabel('Density')
sns.kdeplot(Mexico['HIV_prevalence_adults'], ax = ax1, shade = True, color = 'steelblue')

plt.show()

# %%
#Variable Discreta


fig = plt.figure(figsize = (6, 4))
title = fig.suptitle("Total VIH in Mexico", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax = fig.add_subplot(1,1, 1)
ax.set_xlabel("Year")
ax.set_ylabel("Total VIH")
w_q = Mexico['Total']
w_q = (list(w_q.index), list(w_q.values))
ax.tick_params(axis='both', which='major', labelsize=8.5)
bar = ax.bar(w_q[0], w_q[1], color='steelblue',
        edgecolor='black', linewidth=1)

plt.show()

# %%
# # # Correlation Matrix Heatmap
f, ax = plt.subplots(figsize=(10, 6))
corr = Mexico[['Orphans','Deaths_Adults','Deaths_All_Ages','Deaths_Children','Deaths_Female','Deaths_Male',
                     'Incidence_rate_adults','New_HIV_Infected_Adults','New_HIV_Infected_All_Ages',
                     'New_HIV_Infected_Children']].corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t = f.suptitle('VIH Data Correlation Heatmap', fontsize=12)
plt.show()

# %%
# # Pair-wise Scatter Plots
cols = ['Deaths_Adults','Deaths_Children','Deaths_Female','Deaths_Male']
pp = sns.pairplot(Mexico[cols], size=1.8, aspect=1.8,
                  plot_kws=dict(edgecolor="k", linewidth=0.5),
                  diag_kind="kde", diag_kws=dict(shade=True))

fig = pp.fig
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Mexico VIH Attributes Pairwise Plots', fontsize=14)
plt.show()

# %%
#### Scaling attribute values to avoid few outiers

###
cols = ['Deaths_Adults','Deaths_Children','Deaths_Female','Deaths_Male']
subset_df = Mexico[cols]

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
w_q = Mexico
w_q = pd.DataFrame(list(w_q.index))

scaled_df = ss.fit_transform(subset_df)
scaled_df = pd.DataFrame(scaled_df, columns=cols)

final_df = pd.concat([scaled_df, w_q] , axis=1)

final_df.columns = ['Deaths_Adults','Deaths_Children','Deaths_Female','Deaths_Male','Year']

# %%
### plot parallel coordinates
from pandas.plotting import parallel_coordinates
pc = parallel_coordinates(final_df.loc[20:25], 'Year')
plt.title('Parallel Coordinates Multidimensional Data',weight = 'bold')
plt.show()

# %%
# #Scatter Plot
plt.scatter(Mexico['New_HIV_Infect_Fem_Adults'], Mexico['New_HIV_Infect_Male_Adults'],
            alpha=0.4, edgecolors='w')

plt.xlabel('New Infections Female Adults')
plt.ylabel('New Infections Male Adults')
plt.title('Female New Infections - Male New Infections', y=1.05, weight= 'bold')
# Out:
# Text(0.5,1.05,'Female New Infections - Male New Infections')

# %%
# # Joint Plot
jp = sns.jointplot(x='New_HIV_Infect_Fem_Adults', y='New_HIV_Infect_Male_Adults', data=Mexico,
                   kind='reg', space=0, size=5, ratio=4)

plt.show()
# Out:
# C:\Users\diego\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\diego\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Violin Plots
f, (ax) = plt.subplots(1, 1, figsize=(12, 4))
f.suptitle('New Female VIH Infections - New Male WIH Infections', fontsize=14)

sns.violinplot(x='New_HIV_Infect_Fem_Adults', y='New_HIV_Infect_Male_Adults', data=Mexico,  ax=ax)
ax.set_xlabel("New Female VIH Infections",size = 12,alpha=0.8)
ax.set_ylabel("New Male VIH Infections",size = 12,alpha=0.8)

plt.show()

# %%
#Visualizing 3-D numeric data with a bubble chart
# length, breadth and size
plt.scatter(Mexico['New_HIV_Infect_Fem_Adults'], Mexico['New_HIV_Infect_Male_Adults'], s=Mexico['New_HIV_Infected_Children']*2,
            alpha=0.4, edgecolors='w')

plt.xlabel('New HIV Infections Female')
plt.ylabel('New HIV Infections Male')
plt.title('New HIV Infections Female-New HIV Infections Male-New HIV Infections Children',y=1.05,weight = 'bold')

plt.show()
print(Mexico.New_HIV_Infect_Fem_Adults)
print(Mexico.New_HIV_Infect_Male_Adults)

before_2003 = Mexico.loc[1990:2002]
after_2003 = Mexico.loc[2003:2015]
# Out:
# Year
# 1990    3893.0
# 1991    4430.0
# 1992    4144.0
# 1993    3124.0
# 1994    2358.0
# 1995    1891.0
# 1996    1960.0
# 1997    1762.0
# 1998    1680.0
# 1999    1617.0
# 2000    1725.0
# 2001    1809.0
# 2002    1870.0
# 2003    1972.0
# 2004    2022.0
# 2005    2045.0
# 2006    2187.0
# 2007    2308.0
# 2008    2354.0
# 2009    2212.0
# 2010    2141.0
# 2011    2133.0
# 2012    2350.0
# 2013    2198.0
# 2014    2264.0
# 2015    2330.0
# Name: New_HIV_Infect_Fem_Adults, dtype: float64
# Year
# 1990    23545
# 1991    26443
# 1992    22172
# 1993    17604
# 1994    13990
# 1995    11452
# 1996     9451
# 1997     8475
# 1998     7884
# 1999     7592
# 2000     7321
# 2001     7179
# 2002     7129
# 2003     7080
# 2004     7117
# 2005     7213
# 2006     7233
# 2007     7290
# 2008     7429
# 2009     7760
# 2010     8018
# 2011     8208
# 2012     8165
# 2013     8489
# 2014     8586
# 2015     8678
# Name: New_HIV_Infect_Male_Adults, dtype: int64

# %%
# # Visualizing 3-D mix data using kernel density plots
# # leveraging the concepts of hue for categorical dimension
ax = sns.kdeplot(before_2003['New_HIV_Infect_Fem_Adults'], before_2003['New_HIV_Infect_Male_Adults'],
                  cmap="YlOrBr", shade=True, shade_lowest=False)
ax = sns.kdeplot(after_2003['New_HIV_Infect_Fem_Adults'], after_2003['New_HIV_Infect_Male_Adults'],
                  cmap="Reds", shade=True, shade_lowest=False)
plt.title('Three Dimensions Kernel Density Plot', weight = 'bold')

plt.show()

# %%
# # Visualizing 4-D mix data using scatter plots
# # leveraging the concepts of hue and depth
Mexico['2003'] = ['F','F','F','F','F','F','F','F','F','F','F','F','F','T','T','T','T'\
                    , 'T', 'T', 'T', 'T', 'T','T','T','T','T']

fig = plt.figure(figsize=(8, 6))
t = fig.suptitle('New HIV Infections Female - New HIV Infections Male - New HIV Infections Children - Before After 2003', fontsize=11, weight='bold')
ax = fig.add_subplot(111, projection='3d')

xs = list(Mexico['New_HIV_Infect_Fem_Adults'])
ys = list(Mexico['New_HIV_Infect_Male_Adults'])
zs = list(Mexico['New_HIV_Infected_Children'])
data_points = [(x, y, z) for x, y, z in zip(xs, ys, zs)]
colors = ['red' if wt == 'F' else 'yellow' for wt in list(Mexico['2003'])]

for data, color in zip(data_points, colors):
    x, y, z = data
    ax.scatter(x, y, z, alpha=0.4, c=color, edgecolors='none', s=30)

ax.set_xlabel('New HIV Infections Female')
ax.set_ylabel('New HIV Infections Male')
ax.set_zlabel('New HIV Infections Children')

plt.show()
# Out:
# C:\Users\diego\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Visualizing 4-D mix data using bubble plots
# leveraging the concepts of hue and size

Mexico['2003'] = ['F','F','F','F','F','F','F','F','F','F','F','F','F','T','T','T','T'\
                     , 'T', 'T', 'T', 'T', 'T','T','T','T','T']

size = Mexico['New_HIV_Infected_Children']*1.25
fill_colors = ['#FF9999' if wt=='F' else '#FFE888' for wt in list(Mexico['2003'])]
edge_colors = ['red' if wt=='F' else 'orange' for wt in list(Mexico['2003'])]

plt.scatter(Mexico['New_HIV_Infect_Fem_Adults'], Mexico['New_HIV_Infect_Male_Adults'], s=size,
            alpha=0.4, color=fill_colors, edgecolors=edge_colors)

plt.xlabel('New HIV Infections Female')
plt.ylabel('New HIV Infections Male')
plt.title('New HIV Infections Female - New HIV Infections Male - New HIV Infections Children - Before After 2003', y=1.05, weight='bold')

plt.show()
# Out:
# C:\Users\diego\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# # Overlay 2 histograms to compare them
data1 = Mexico['Deaths_Female']
data2 = Mexico['Deaths_Male']

def overlaid_histogram(data1, data2, n_bins = 0, data1_name="Deaths", data1_color="#539caf", data2_name="", data2_color="#7663b0", x_label="", y_label="", title=""):
    # Set the bounds for the bins so that the two distributions are fairly compared
    max_nbins = 10
    data_range = [min(min(data1), min(data2)), max(max(data1), max(data2))]
    binwidth = (data_range[1] - data_range[0]) / max_nbins


    if n_bins == 0:
    	bins = np.arange(data_range[0], data_range[1] + binwidth, binwidth)
    else:
    	bins = n_bins

    # Create the plot
    _, ax = plt.subplots()
    ax.hist(data1, bins = bins, color = data1_color, alpha = 1, label = data1_name)
    ax.hist(data2, bins = bins, color = data2_color, alpha = 0.75, label = data2_name)
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.legend(loc = 'best')

    plt.show()

# %%
overlaid_histogram(data1 , data2 , n_bins=15, data1_name='Deaths Male', data2_name= 'Deaths Female', data1_color="#7663b0", data2_color='#539caf',x_label='Deaths Male', y_label='Deaths Female', title='Deaths Female-Male VIH' )
#

# %%
n = 500
x = 2 + 2*np.random.standard_normal(n)
y = 2 + 2*np.random.standard_normal(n)

p = figure(title="Hexbin for 500 points", match_aspect=True,
           tools="wheel_zoom,reset", background_fill_color='#440154')
p.grid.visible = False

r, bins = p.hexbin(x, y, size=0.5, hover_color="pink", hover_alpha=0.8)

p.circle(x, y, color="white", size=1)

hover = HoverTool(tooltips=[("count", "@c"), ("(q,r)", "(@q, @r)")],
                  mode="mouse", point_policy="follow_mouse", renderers=[r])

p.add_tools(hover)

output_file("hexbin.html")

show(p)
